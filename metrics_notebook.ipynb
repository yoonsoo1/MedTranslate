# %%
# !pip -q install transformers
# !pip -q install sentencepiece
# !pip -q install sentence_transformers
# !pip -q install textstat
# !pip -q install rouge-score
# !pip -q install evaluate
# !pip -q install sacremoses
# !pip -q install sacrebleu
from rouge_score import rouge_scorer
from evaluate import load
import pandas as pd
import numpy as np
import re
import textstat
import pickle
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 2.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount("/content/drive/")
# %cd "./drive/My Drive"
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive

# %% [markdown]
# ### Load data

# %%
X_dev = pd.read_csv("./processed_dev_data.csv")
X_test = pd.read_csv("./processed_test_data.csv")

# %%
with open("student_dev_output_no_prompts.pkl", "rb") as f:
  y_student_dev = pickle.load(f)

with open("student_test_output_no_prompts.pkl", "rb") as f:
  y_student_test = pickle.load(f)

with open("teacher_dev_output.pkl", "rb") as f:
  y_teacher_dev = pickle.load(f)

with open("teacher_test_output.pkl", "rb") as f:
  y_teacher_test = pickle.load(f)

# %% [markdown]
# ### Metrics

# %%
sari = load("sari")

# %%
def rouge(output, gen):
  scorer = rouge_scorer.RougeScorer(['rouge1', 'rougeL'], use_stemmer=True)
  scores = scorer.score(output, gen)
  return scores

# %%
def flesch(text):

  if (text == ""):
    return 0, 0

  # Remove non-alphabetic characters and digits
  clean_text = re.sub(r'[^a-zA-Z\s]', '', text)

  # Calculate average number of words per sentence
  words_per_sentence = textstat.lexicon_count(clean_text) / textstat.sentence_count(text)

  # Calculate average number of syllables per word
  syllables_per_word = textstat.syllable_count(clean_text) / textstat.lexicon_count(clean_text)

  # Calculate Flesch scores
  fre_score = 206.835 - 1.015 * words_per_sentence - 84.6 * syllables_per_word
  fkgl_score = 0.39 * words_per_sentence + 11.8 * syllables_per_word - 15.59

  return fre_score, fkgl_score

# %%
def compute_sari(X, y, ref):
  sources = [X]
  predictions = [y]
  references = [[ref]]
  return(sari.compute(sources=sources, predictions=predictions, references=references)["sari"])

# %% [markdown]
# ### Validation scores

# %%
# Student dev
rouge1_f_dev = 0.0
rougeL_f_dev = 0.0

for i in range(len(X_dev)):
  scores = rouge(X_dev["Expert"].values[i], y_student_dev[i])
  rouge1_f_dev += scores["rouge1"].fmeasure
  rougeL_f_dev += scores["rougeL"].fmeasure

rouge1_f_dev /= len(X_dev)
rougeL_f_dev /= len(X_dev)

print(f"ROUGE-1 F-measure: {rouge1_f_dev}")
print(f"ROUGE-L F-measure: {rougeL_f_dev}")
# Out:
# ROUGE-1 F-measure: 0.8066125130779112
# ROUGE-L F-measure: 0.8008735147445086

# %%
# Teacher dev
rouge1_f_dev = 0.0
rougeL_f_dev = 0.0

for i in range(len(X_dev)):
  scores = rouge(X_dev["Expert"].values[i], y_teacher_dev[i])
  rouge1_f_dev += scores["rouge1"].fmeasure
  rougeL_f_dev += scores["rougeL"].fmeasure

rouge1_f_dev /= len(X_dev)
rougeL_f_dev /= len(X_dev)

print(f"ROUGE-1 F-measure: {rouge1_f_dev}")
print(f"ROUGE-L F-measure: {rougeL_f_dev}")
# Out:
# ROUGE-1 F-measure: 0.6851174307198339
# ROUGE-L F-measure: 0.660336441935362

# %%
# Original Simple
rouge1_f_dev = 0.0
rougeL_f_dev = 0.0

for i in range(len(X_dev)):
  scores = rouge(X_dev["Expert"].values[i], X_dev["Simple"].values[i])
  rouge1_f_dev += scores["rouge1"].fmeasure
  rougeL_f_dev += scores["rougeL"].fmeasure

rouge1_f_dev /= len(X_dev)
rougeL_f_dev /= len(X_dev)

print(f"ROUGE-1 F-measure: {rouge1_f_dev}")
print(f"ROUGE-L F-measure: {rougeL_f_dev}")
# Out:
# ROUGE-1 F-measure: 0.5439899701984097
# ROUGE-L F-measure: 0.4990515538425681

# %%
# Original Expert
fre_dev = 0.0
fkgl_dev = 0.0

for x in X_dev["Expert"].values:
  fre, fkgl = flesch(x)
  fre_dev += fre
  fkgl_dev += fkgl


fre_dev /= len(X_dev)
fkgl_dev /= len(X_dev)

print(f"Flesch Reading Ease Score: {fre_dev}")
print(f"Flesch Kincaid Grade Level: {fkgl_dev}")
# Out:
# Flesch Reading Ease Score: 36.826087809038576
# Flesch Kincaid Grade Level: 13.026700713356318

# %%
# Original Simple
fre_dev = 0.0
fkgl_dev = 0.0

for x in X_dev["Simple"].values:
  fre, fkgl = flesch(x)
  fre_dev += fre
  fkgl_dev += fkgl


fre_dev /= len(X_dev)
fkgl_dev /= len(X_dev)

print(f"Flesch Reading Ease Score: {fre_dev}")
print(f"Flesch Kincaid Grade Level: {fkgl_dev}")
# Out:
# Flesch Reading Ease Score: 49.10630040968796
# Flesch Kincaid Grade Level: 11.5716440127897

# %%
# Student
fre_dev = 0.0
fkgl_dev = 0.0

for y in y_student_dev:
  fre, fkgl = flesch(y)
  fre_dev += fre
  fkgl_dev += fkgl

fre_dev /= len(X_dev)
fkgl_dev /= len(X_dev)

print(f"Flesch Reading Ease Score: {fre_dev}")
print(f"Flesch Kincaid Grade Level: {fkgl_dev}")
# Out:
# Flesch Reading Ease Score: 31.318027892589058
# Flesch Kincaid Grade Level: 13.211549544275194

# %%
# Teacher
fre_dev = 0.0
fkgl_dev = 0.0

for y in y_teacher_dev:
  fre, fkgl = flesch(y)
  fre_dev += fre
  fkgl_dev += fkgl

fre_dev /= len(X_dev)
fkgl_dev /= len(X_dev)

print(f"Flesch Reading Ease Score: {fre_dev}")
print(f"Flesch Kincaid Grade Level: {fkgl_dev}")
# Out:
# Flesch Reading Ease Score: 48.936040195240615
# Flesch Kincaid Grade Level: 10.715099471891381

# %%
# Student
sari_score_dev = 0.0

for i in range(len(X_dev)):
  sari_score_dev += compute_sari(X_dev["Expert"].values[i],
                             y_student_dev[i],
                             X_dev["Simple"].values[i])

sari_score_dev /= len(X_dev)

print(f"Sari Score: {sari_score_dev}")
# Out:
# Sari Score: 40.961821885002955

# %%
# Teacher
sari_score_dev = 0.0

for i in range(len(X_dev)):
  sari_score_dev += compute_sari(X_dev["Expert"].values[i],
                             y_teacher_dev[i],
                             X_dev["Simple"].values[i])

sari_score_dev /= len(X_dev)

print(f"Sari Score: {sari_score_dev}")
# Out:
# Sari Score: 43.909374453978636

# %% [markdown]
# ### Test scores

# %%
# Student
rouge1_f_test = 0.0
rougeL_f_test = 0.0

for i in range(len(X_test)):
  scores = rouge(X_test["Expert"].values[i], y_student_test[i])
  rouge1_f_test += scores["rouge1"].fmeasure
  rougeL_f_test += scores["rougeL"].fmeasure

rouge1_f_test /= len(X_test)
rougeL_f_test /= len(X_test)

print(f"ROUGE-1 F-measure: {rouge1_f_test}")
print(f"ROUGE-L F-measure: {rougeL_f_test}")
# Out:
# ROUGE-1 F-measure: 0.8229392908677232
# ROUGE-L F-measure: 0.8175084154689236

# %%
# Teacher
rouge1_f_test = 0.0
rougeL_f_test = 0.0

for i in range(len(X_test)):
  scores = rouge(X_test["Expert"].values[i], y_teacher_test[i])
  rouge1_f_test += scores["rouge1"].fmeasure
  rougeL_f_test += scores["rougeL"].fmeasure

rouge1_f_test /= len(X_test)
rougeL_f_test /= len(X_test)

print(f"ROUGE-1 F-measure: {rouge1_f_test}")
print(f"ROUGE-L F-measure: {rougeL_f_test}")
# Out:
# ROUGE-1 F-measure: 0.7006819399606844
# ROUGE-L F-measure: 0.6774642757408771

# %%
# Dataset simple
rouge1_f_test = 0.0
rougeL_f_test = 0.0

for i in range(len(X_test)):
  scores = rouge(X_test["Expert"].values[i], X_test["Simple"].values[i])
  rouge1_f_test += scores["rouge1"].fmeasure
  rougeL_f_test += scores["rougeL"].fmeasure

rouge1_f_test /= len(X_test)
rougeL_f_test /= len(X_test)

print(f"ROUGE-1 F-measure: {rouge1_f_test}")
print(f"ROUGE-L F-measure: {rougeL_f_test}")
# Out:
# ROUGE-1 F-measure: 0.5259428633457133
# ROUGE-L F-measure: 0.4830311462346027

# %%
# Original medical text
fre_test = 0.0
fkgl_test = 0.0

for x in X_test["Expert"].values:
  fre, fkgl = flesch(x)
  fre_test += fre
  fkgl_test += fkgl


fre_test /= len(X_test)
fkgl_test /= len(X_test)

print(f"Flesch Reading Ease Score: {fre_test}")
print(f"Flesch Kincaid Grade Level: {fkgl_test}")
# Out:
# Flesch Reading Ease Score: 39.646411957824604
# Flesch Kincaid Grade Level: 12.258081970815644

# %%
# Simple medical text
fre_test = 0.0
fkgl_test = 0.0

for x in X_test["Simple"].values:
  fre, fkgl = flesch(x)
  fre_test += fre
  fkgl_test += fkgl


fre_test /= len(X_test)
fkgl_test /= len(X_test)

print(f"Flesch Reading Ease Score: {fre_test}")
print(f"Flesch Kincaid Grade Level: {fkgl_test}")
# Out:
# Flesch Reading Ease Score: 53.100896209940565
# Flesch Kincaid Grade Level: 10.239037530776054

# %%
# Student
fre_test = 0.0
fkgl_test = 0.0

for y in y_student_test:
  fre, fkgl = flesch(y)
  fre_test += fre
  fkgl_test += fkgl

fre_test /= len(X_test)
fkgl_test /= len(X_test)

print(f"Flesch Reading Ease Score: {fre_test}")
print(f"Flesch Kincaid Grade Level: {fkgl_test}")
# Out:
# Flesch Reading Ease Score: 39.28209262859046
# Flesch Kincaid Grade Level: 11.763749652408329

# %%
# Teacher
fre_test = 0.0
fkgl_test = 0.0

for y in y_teacher_test:
  fre, fkgl = flesch(y)
  fre_test += fre
  fkgl_test += fkgl

fre_test /= len(X_test)
fkgl_test /= len(X_test)

print(f"Flesch Reading Ease Score: {fre_test}")
print(f"Flesch Kincaid Grade Level: {fkgl_test}")
# Out:
# Flesch Reading Ease Score: 50.7915697290646
# Flesch Kincaid Grade Level: 10.43214894243939

# %%
# Student
sari_score_test = 0.0

for i in range(len(X_test)):
  sari_score_test += compute_sari(X_test["Expert"].values[i],
                             y_student_test[i],
                             X_test["Simple"].values[i])

sari_score_test /= len(X_test)

print(f"Sari Score: {sari_score_test}")
# Out:
# Sari Score: 41.45003621398768

# %%
# Teacher
sari_score_test = 0.0

for i in range(len(X_test)):
  sari_score_test += compute_sari(X_test["Expert"].values[i],
                             y_teacher_test[i],
                             X_test["Simple"].values[i])

sari_score_test /= len(X_test)

print(f"Sari Score: {sari_score_test}")
# Out:
# Sari Score: 45.76244494468783

# %%
for i in range(len(X_dev)):
  print(f"Expert: {X_dev['Expert'].values[i]}")
  print(f"Simple: {X_dev['Simple'].values[i]}")
  print(f"Teacher: {y_teacher_dev[i]}")
  print(f"Student: {y_student_dev[i]}")
  print("============================================")
# Out:
# Expert: Nonsurgical treatment fails in about 40 to 70 % of patients, necessitating surgical excision.
# Simple: In about 40 to 70 % of people, surgical removal may be necessary.
# Teacher: Nonsurgical treatment fails in about 40 to 70 % of people, requiring surgical excision.
# Student: Nonsurgical treatment fails in about 40 to 70 % of patients, necessitating surgical excision.
# ============================================
# Expert: In about 10 to 20 % of patients, discrete pink, blanching lesions (rose spots) appear in crops on the chest and abdomen during the 2nd wk and resolve in 2 to 5 days.
# Simple: During the second week, a rash of flat, rose-colored spots develops on the chest and abdomen of about 10 to 20 % of people.
# Teacher: During the 2nd week, small, raised sores (rose spots) appear on the chest and abdomen. They resolve in about 2 to 5 days, and the sores usually subside within a few days.
# Student: In about 10 % of patients, discrete pink, blanching lesions (rose spots) appear in crops on the chest and abdomen during the 2nd wk and resolve in 2 to 5 days.
# ============================================
# Expert: Most strabismus is caused by Refractive error; Muscle imbalance.
# Simple: In children 6 months of age or older, strabismus is often caused by a refractive error (excessive farsightedness [ hyperopia ]) or an imbalance in the pull of muscles that control the position of the eyes.
# Teacher: Most strabismus is caused by a refractive error; Muscle imbalance.
# Student: Most strabismus is caused by Refractive error Muscle imbalance.
# ============================================
# Expert: For patients without a clear cause but no red flag findings, many clinicians empirically begin treatment for postnasal drip (eg, antihistamine and decongestant combinations, nasal corticosteroid sprays, or nasal muscarinic antagonist sprays) or gastroesophageal reflux disease (eg, proton pump inhibitors, H2 blockers).
# Simple: If the examination does not suggest a cause of a cough and no warning signs are present, many doctors try giving people a drug to treat one of two common causes of cough: An antihistamine/decongestant combination or a nasal corticosteroid or nasal muscarinic antagonist spray (for postnasal drip); A proton pump inhibitor or histamine-2 (H2) blocker (for gastroesophageal reflux disease).
# Teacher: For patients without a clear cause but no red flag findings, many clinicians begin treatment for postnasal drip or GERD.
# Student: For patients without a clear cause but no red flag findings, many clinicians empirically begin treatment for postnasal drip (eg, antihistamine and decongestant combinations, nasal corticosteroid sprays, or nasal muscarinic antagonist sprays) or gastroesophageal reflux disease (eg, proton pump inhibitors, H2 blockers).
# ============================================
# Expert: The authors remark that the reaction appears to be influenced by the polarity of the solvent, and this can be explained by the change in the dipole moments when going from reactant to transition state to product.
# Simple: The authors say that the reaction appears to be influenced by the polarity of the solvent, and this can be shown by the change in the dipole moments when going from reactant to transition state to product.
# Teacher: The authors say that the reaction appears to be influenced by the polarity of the solvent, and this can be shown by the change in the dipole moments when going from reactant to transition state to product.
# Student: The authors remark that the reaction appears to be influenced by the polarity of the solvent, and this can be explained by the change in the dipole moments when going from reactant to transition state to product.
# ============================================
# Expert: The inner ear is innervated by the eighth cranial nerve in all vertebrates.
# Simple: The inner ear is supplied with the eighth cranial nerve in all vertebrates.
# Teacher: The inner ear is not the sense organ of an animal.
# Student: The inner ear is innervated by the eighth cranial nerve in all vertebrates.
# ============================================
# Expert: Microbial cultures are rarely done because a valid culture requires a sample obtained by sinus endoscopy or sinus puncture; culturing a swab of nasal secretions is inadequate. Cultures are typically done only when empiric treatment fails and in immunocompromised patients and some hospital- acquired causes of sinusitis.
# Simple: Sometimes a doctor passes a thin viewing scope (endoscope) into the nose to inspect the sinus openings and to obtain samples of fluid for culture. This procedure, which requires a local anesthetic (to numb the area), can be done in the doctor's office.
# Teacher: Microbial cultures are rarely done because a valid culture requires a sample obtained by sinus endoscopy or sinus puncture; culturing a swab of nasal secretions is inadequate. Cultures are typically done only when empiric treatment fails, in immunocompromised patients and some hospital- acquired causes of sinusitis.
# Student: culture is rarely done because a valid culture requires a sample obtained by sinus endoscopy or sinus puncture culturing a swab of nasal secretions is inadequate. Cultures are typically done only when empiric treatment fails and in immunocompromised patients and some hospital- acquired causes of sinusitis.
# ============================================
# Expert: A cerebral infarction is an area of necrotic tissue in the brain resulting from a blockage or narrowing in the arteries supplying blood and oxygen to the brain.
# Simple: A cerebral infarction is an area of necrotic tissue in the brain caused from a blockage or narrowing in the arteries supplying blood and oxygen to the brain.
# Teacher: A cerebral infarction is a type of stroke wherein the arteries supplying blood and oxygen to the brain become blocked.
# Student: A cerebral infarction is a area of necrotic tissue in the brain resulting from a blockage or narrowing in the arteries supplying blood and oxygen to the brain.
# ============================================
# Expert: Hepatic steatosis is often asymptomatic.
# Simple: Fatty liver often causes no symptoms.
# Teacher: Sometimes, hepatic steatosis is unnoticed.
# Student: Hepatic steatosis is often asymptomatic.
# ============================================
# Expert: In adults, symptoms are similar to those of children, including sore throat, fever, dysphagia, and drooling, but peak symptoms usually take > 24 h to develop. Because of the larger diameter of the adult airway, obstruction is less common and less fulminant. A delay in diagnosis and treatment increases the risk of airway obstruction and death.
# Simple: In adults with epiglottitis, symptoms are similar to those of children, including sore throat, fever, difficulty swallowing, and drooling, but symptoms usually take more than 24 hours to develop. Because the adult airway is larger, blockage of the airway is less common and less sudden. However, the airway can still become blocked, and adults may die if diagnosis and treatment are delayed.
# Teacher: In adults, symptoms are similar to those of children, including sore throat, fever, and a swollen throat. Because the adult airway is larger, obstruction is less common and less fulminant. If left untreated, obstruction is more serious and can lead to death.
# Student: drooling, but peak symptoms usually take > 24 h to develop. Because of the larger diameter of the adult airway, obstruction is less common and less fulminant. A delay in diagnosis and treatment increases the risk of obstruction and death.
# ============================================
# Expert: Huntington disease progresses, making walking impossible and swallowing difficult; it results in severe dementia.
# Simple: Eventually, the entire body is affected, making walking, sitting still, eating, speaking, and dressing extremely difficult. In advanced disease, dementia is severe, and people are confined to bed.
# Teacher: As Huntington disease progresses, it makes walking impossible and swallowing difficult.
# Student: Huntington disease progresses, making walking impossible and swallowing difficult it results in severe dementia.
# ============================================
# Expert: Most people with panic disorder anticipate and worry about another attack (anticipatory anxiety) and avoid places or situations where they have previously panicked. People with panic disorder often worry that they have a dangerous heart, lung, or brain disorder and repeatedly visit their family physician or an emergency department seeking help.
# Simple: Because symptoms of a panic attack involve many vital organs, people often worry that they have a dangerous medical problem involving the heart, lungs, or brain. For example, a panic attack can feel like a heart attack. Thus, people may repeatedly visit their family doctor or a hospital emergency department.
# Teacher: About 15 percent of people with panic disorder worry that they have a dangerous heart, lung, or brain disorder and repeatedly visit their family physician or an emergency department seeking help.
# Student: Most people with panic disorder anticipate and worry about another attack (anticipatory anxiety) and avoid places or situations where they have previously panicked. People with panic disorder often worry that they have a dangerous heart, lung, or brain disorder and repeatedly visit their family physician or an emergency department seeking help.
# ============================================
# Expert: Allergic bronchopulmonary aspergillosis, a hypersensitivity reaction to Aspergillus species that occurs most commonly in people with asthma, but sometimes in patients with CF, can cause or contribute to bronchiectasis.
# Simple: Allergic bronchopulmonary aspergillosis, which affects the larger airways, can cause mucus plugs that block the airways and lead to bronchiectasis. It is an allergic reaction to the fungus Aspergillus and occurs most commonly in people with asthma or cystic fibrosis.
# Teacher: Allergic bronchopulmonary aspergillosis, a hypersensitivity reaction to Aspergillus species, usually occurs in people with asthma, but sometimes in people with CF.
# Student: Allergic bronchopulmonary aspergillosis, a hypersensitivity reaction to Aspergillus species that occurs most commonly in people with asthma, but sometimes in patients with CF, can cause or contribute to bronchiectasis.
# ============================================
# Expert: Mammals share the same reproductive system, including the regulatory hypothalamic system that releases gonadotropin releasing hormone in pulses, the pituitary that secretes follicle stimulating hormone and luteinizing hormone, and the ovary itself that releases sex hormones including estrogens and progesterone.
# Simple: Mammals share the same reproductive system, including the regulatory hypothalamic system that releases gonadotropin-releasing hormone in pulses, the pituitary that secretes follicle-stimulating hormone and luteinizing hormone, and the ovary itself releases sex hormones like estrogens and progesterone.
# Teacher: Mammals share the same reproductive system, including the regulatory hypothalamus that releases gonadotropin releasing hormone in pulses, the pituitary that releases follicle stimulating hormone, luteinizing hormone, and the ovary itself that releases sex hormones including estrogens and progesterone.
# Student: Mammals share the same reproductive system, including the regulatory hypothalamic system that releases gonadotropin releasing hormone in pulses, the pituitary that secretes follicle stimulating hormone and luteinizing hormone, and the ovary itself that releases sex hormones including estrogens and progesterone.
# ============================================
# Expert: Shepard had suffered fractures to the back of his head and in front of his right ear.
# Simple: Shepard was in a coma and suffered fractures to the back of his head and the front of his right ear.
# Teacher: Shepard had suffered fractures to the back of his head and in front of his right ear.
# Student: $   Shepard hatte erkrankt, er hatte tiefe Brücken in den Rücken und vor der rechten Ohr.
# ============================================
# Expert: If doubt exists, biopsy should include the full depth of the dermis and extend slightly beyond the edges of the lesion.
# Simple: If these or other findings lead doctors to suspect melanoma, they do a biopsy. For the biopsy, doctors remove the entire growth if it is small or only part of it if it is large. They then examine the sample under a microscope to determine whether the growth is a melanoma and, if so, whether all the cancer has been removed. If the biopsy shows that the growth is a melanoma and the growth has not been completely removed, it is then completely removed.
# Teacher: If biopsy is needed, it should include the full depth of the dermis and extend slightly beyond the edges of the lesion.
# Student: Die biopsy sollte die vollständige Tiefe der dermis enthalten und sich leicht über die Rand der Lesion hinaus erstrecken.
# ============================================
# Expert: Positron emission tomography (PET), single -photon emission computed tomography (SPECT), or functional MRI may be done to further assess cerebral function if the diagnosis is in doubt. In patients with locked-in syndrome, electroencephalography (EEG) shows normal sleep -wake patterns.
# Simple: If the diagnosis is in doubt, doctors may do other imaging tests, such as positron emission tomography (PET), single -photon emission computed tomography (SPECT), evoked responses, or electroencephalography.
# Teacher: Electroencephalography (EEG) shows normal sleep -wake patterns.
# Student: (SEM) syndrome, syndrome, or locked-in syndrome, electroencephalography (EEG) shows normal sleep -wake patterns.
# ============================================
# Expert: The diagnosis of nonspecific interstitial pneumonia should be considered in patients with unexplained subacute or chronic cough and dyspnea. Diagnosis requires HRCT and always requires confirmation by surgical lung biopsy. NSIP is a diagnosis of exclusion that requires careful clinical review for possible alternative disorders, in particular connective tissue disorders, hypersensitivity pneumonitis, and drug toxicity. Chest x-ray primarily shows lower-zone reticular opacities. Bilateral patchy opacities are also possible. HRCT findings include bilateral patchy ground- glass attenuation, irregular lines, and bronchial dilation (traction bronchiectasis), generally with a lower lung zone distribution.
# Simple: As with other idiopathic interstitial pneumonias, chest x-rays and computed tomography (CT) are done.
# Teacher: Patients with cough that is not cough-like should have their airways examined for signs of a lung problem.
# Student: ,, and lower-zone reticular opacities. Bilateral patchy opacities are also possible. NSIP is a diagnosis of exclusion that requires careful clinical review for possible alternative disorders. NSIP is a diagnosis of exclusion that requires careful clinical review for possible alternative disorders.
# ============================================
# Expert: It is distinguished from hyperplasia, in which the cells remain approximately the same size but increase in number.
# Simple: It should be distinguished from hyperplasia, in which the cells remain approximately the same size but increase in number.
# Teacher: It is distinguished from hyperplasia, in which the cells remain about the same size but multiply.
# Student: Es unterscheidet sich von Hyperplasia, in der die Zellen ungefähr die gleiche Größe haben, aber wachsen.
# ============================================
# Expert: Hot flushes (hot flashes, night sweats) due to vasomotor instability affect 75 to 85 % of women and usually begin before menses stop Vasomotor symptoms last an average of 7.4 yr and can persist for > 10 yr in some groups of women (1). Women feel warm or hot and may perspire, sometimes profusely; core temperature increases. The skin, especially of the face, head, and neck, may become red and warm. The episodic flush, which may last from 30 sec to 5 min, may be followed by chills. Flushes may manifest during the night as night sweats.
# Simple: Hot flashes affect 75 to 85 % of women. They usually begin before periods stop. They last for an average of almost 7 1/2 years but can last more than 10 years. During a hot flash, blood vessels near the skin surface widen (dilate). As a result, blood flow increases, causing the skin, especially on the head and neck, to become red and warm (flushed). Women feel warm or hot, and perspiration may be profuse. Hot flashes are sometimes called hot flushes because the face can become red. A hot flash lasts from 30 seconds to 5 minutes and may be followed by chills. Night sweats are hot flashes that occur at night.
# Teacher: Hot flushes (hot flashes, night sweats) are common. They usually begin before menses stop.
# Student: .    Hot flushes (hot flashes, night sweats) due to vasomotor instability affect 75 to 85 % of women. Hot flushes (hot flashes, night sweats) due to vasomotor instability affect 75 to 85 % of women.
# ============================================
# Expert: In one third of patients, the liver is enlarged and smooth, but it is not usually tender.
# Simple: In one third of people, the liver is enlarged and smooth but is not usually tender.
# Teacher: In about one third of people, the liver is enlarged and not usually tender.
# Student: In one third of patients, the liver is enlarged and smooth, but it is not usually tender.
# ============================================
# Expert: Edema of the intestines may cause nausea, vomiting, colicky abdominal pain, and/or diarrhea.
# Simple: Occasionally, the digestive tract is involved, resulting in nausea, vomiting, crampy abdominal pain, or diarrhea.
# Teacher: Some people have nausea, vomiting, and a painful, bloated feeling in the abdomen.
# Student: Edema of the intestines may cause nausea, vomiting, colicky abdominal pain, and/or diarrhea.
# ============================================
# Expert: If initial presentation is less acute, an upper GI series with small- bowel follow-through and spot films of the terminal ileum is preferred over conventional CT. However, newer techniques of CT or MR enterography, which combine high - resolution CT or MR imaging with large volumes of ingested contrast, are becoming the procedures of choice in some centers.
# Simple: People who have had symptoms that recur over a period of time may have x-rays taken of the stomach and small intestine after drinking liquid barium (called an upper gastrointestinal [ GI ] series) or have x-rays taken after receiving barium as an enema (called a barium enema). Newer approaches include CT enterography or magnetic resonance enterography.
# Teacher: If the initial presentation is less acute, an upper GI series with small - bowel follow- through and spot films of the terminal ileum is preferred over conventional CT.
# Student: ,ography, and MR enterography are becoming the preferred procedure in some centers.
# ============================================
# Expert: Bulbar and palpebral conjunctival injection and a transient flushing or pale pink macular rash (particularly of the face) may occur. Cervical, epitrochlear, and inguinal lymph nodes are often enlarged.
# Simple: Lymph nodes are swollen, and a rash that makes the face look flushed and red may appear briefly.
# Teacher: Sometimes, the lymph nodes from the head to the tip of the spine become swollen, and pus may build up in the neck and back.
# Student: Bulbar and palpebral conjunctival injection and a transient flushing or pale pink macular rash (particularly of the face) may occur. Cervical, epitrochlear, and inguinal lymph nodes are often enlarged.
# ============================================
# Expert: Children usually outgrow these manifestations and react increasingly to inhaled allergens, with symptoms of asthma and rhinitis; this progression is called atopic march. By age 10 years, patients rarely have respiratory symptoms after the allergenic food is eaten, even though skin tests remain positive.
# Simple: By about age 1 year, the rash tends to develop less often, but children may start to react to inhaled allergens (such as pollen) and have asthma symptoms. They may wheeze, feel short of breath, or get a runny nose when they eat the food that triggers their allergy. By about age 10, children rarely have asthma symptoms after the food is eaten.
# Teacher: At about age 5 or 6, most children develop asthma. However, by age 10 or 11 most children have no symptoms after eating the allergenic food.
# Student: $$    Children usually outgrow these manifestations and react increasingly to inhaled allergens, with symptoms of asthma and rhinitis. This progression is called atopic march. By age 10 years, patients rarely have respiratory symptoms after the allergenic food is eaten, even though skin tests remain positive.
# ============================================
# Expert: A pulmonary contusion , also known as lung contusion , is a bruise of the lung , caused by chest trauma .
# Simple: A pulmonary contusion ( or lung contusion ) is a contusion ( bruise ) of the lung , caused by chest trauma .
# Teacher: A pulmonary contusion, or lung contusion, is a bruise of the lung, usually after a chest injury.
# Student: A pulmonary contusion, also known as lung contusion, is a bruise of the lung, caused by chest trauma.
# ============================================
# Expert: For example, the color (eg, yellow, green) and thickness of sputum do not help differentiate bacterial from other causes.
# Simple: For example, whether sputum is yellow or green or thick or thin does not help distinguish bacterial infection from other possible causes.
# Teacher: For example, the color (eg, yellow, green) and thickness of sputum do not help differentiate bacterial from other causes.
# Student: , a bacterial bacterial is a bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial bacterial
# ============================================
# Expert: Generally the component parts have boiling points that differ by less than 25 Â°C from each other under a pressure of one atmosphere .
# Simple: Generally , the component parts boil at less than 25 Â°C from each other under a pressure of one atmosphere ( atm ) .
# Teacher: Generally the component parts have boiling points that differ by less than 25 °C each other under pressure of one atmosphere.
# Student: Generally the component parts have boiling points that differ by less than 25 °C from each other under a pressure of one atmosphere.
# ============================================
# Expert: DBS is approved in the United States by the Food and Drug Administration for the treatment of Parkinson 's.
# Simple: DBS was approved in the United States by the Food and Drug Administration for the treatment of Parkinson 's in 2002.
# Teacher: DBS is approved in the United States by the Food and Drug Administration for the treatment of Parkinson's.
# Student: DBS is approved in the United States by the Food and Drug Administration for the treatment of Parkinson's.
# ============================================
# Expert: More widespread cancer may cause obstructive uropathy, back pain, and leg swelling due to venous or lymphatic obstruction.
# Simple: If the cancer is widespread, it can cause lower back pain and swelling of the legs. The urinary tract may be blocked, and without treatment, kidney failure and death can result.
# Teacher: More widespread cancer may cause obstructive uropathy, back pain, and swelling of the legs and back.
# Student: More widespread cancer may cause obstructive uropathy, back pain, and leg swelling due to venous or lymphatic obstruction.
# ============================================
# Expert: Grignard reagents react with a variety of carbonyl derivatives.
# Simple: Grignard reagents will react with a variety of carbonyl derivatives.
# Teacher: In addition, Grignard reagents will react with electrophiles.
# Student: reagents react with a variety of carbonyl derivatives.
# ============================================
# Expert: The glans penis is the expanded cap of the corpus spongiosum .
# Simple: The glans penis is a cap around the corpus spongiosum .
#
# Teacher: The glans penis is the expanded cap of the corpus spongiosum.
# Student: Die glans penis ist die glühende Kappe des corpus spongiosum.
# ============================================
# Expert: In children, sore throat, odynophagia, and dysphagia develop abruptly. Fatal asphyxia may occur within a few hours of onset. Drooling is very common.
# Simple: In children with epiglottitis, symptoms develop suddenly, and fatal narrowing of the larynx can occur within a few hours of the start of symptoms. Symptoms include Severe throat pain; Difficulty swallowing; Pain with swallowing; Fever; Drooling; A muffled voice.
# Teacher: In children, sore throat, odynophagia, and dysphagia (laryngitis) (choking pain) develop suddenly. If left untreated, it may progress to asphyxiation within hours. If left untreated, it may continue for days or weeks.
# Student: ,, and dysphagia develop abruptly. Fatal asphyxia may occur within a few hours of onset. Fatal asphyxia may occur within a few hours of onset.
# ============================================
# Expert: Anxiety can arise suddenly, as in panic, or gradually over many minutes, hours, or days.
# Simple: Anxiety can arise suddenly, as in panic, or gradually over minutes, hours, or days.
# Teacher: Anxiety can arise suddenly, as in panic, or gradually over many minutes, hours, or days.
# Student: Anxiety can arise suddenly, as in panic, or gradually over many minutes, hours, or days.
# ============================================
# Expert: However, at the age of 18, he predeceased his father when he died of typhoid fever.
# Simple: However, he died before his father because of typhoid fever.
# Teacher: At age 18, he predeceased his father when he died of typhoid fever.
# Student: Allerdings, he predeceased his father at the age of 18 when he died of typhoid fever.
# ============================================
# Expert: After Ross there was no further exploration of the Weddell Sea until 1903, when William Speirs Bruce took Scotia to 74 Â°1 'S, but in a sector of the sea which did not bring him close to Morrell 's or Ross 's supposed sightings.
# Simple: There was no further penetration of the Weddell Sea until 1903, when William Speirs Bruce took Scotia to 74 Â°1 'S, but in a sector of the sea which did not bring him close to Morrell 's or Ross 's sightings.
# Teacher: After Ross there was no more exploration of the Weddell Sea until 1903, when William Speirs Bruce took Scotia to 74 °1 'S, but in a sector which did not bring him close to Morrell's or Ross's supposed sightings.
# Student: After Ross there was no further exploration of the Weddell Sea until 1903, when William Speirs Bruce took Scotia to 74 °1 'S, but in a sector of the sea which did not bring him close to Ross's supposed sightings.
# ============================================
# Expert: A few patients with breast cancer present with signs of metastatic disease (eg, pathologic fracture, pulmonary dysfunction).
# Simple: Occasionally, the first symptom occurs only when the cancer spreads to another organ. For example, if it spreads to a bone, the bone may ache or become weak, resulting in a fracture.
# Teacher: A few women with breast cancer have signs of metastatic disease.
# Student:
# ============================================
# Expert: AIDS patients may require lifelong maintenance therapy with itraconazole for meningeal and disseminated infection.
# Simple: After the infection is controlled, people with AIDS or another condition that weakens the immune system may need to take itraconazole by mouth until their immune system has recovered, possibly for the rest of their life. Itraconazole helps prevent sporotrichosis from recurring while the immune system is weak.
# Teacher: AIDS patients may require lifelong maintenance therapy with itraconazole for meningeal and disseminated infection.
# Student: AIDS patients may require lifelong maintenance therapy with itraconazole for meningeal and disseminated infection.
# ============================================
# Expert: A few years later it lost approximately half of its population to the Black Death.
# Simple: A few years later Perpignan lost approximately half of its population to the Black Death.
# Teacher: About half of its population died of the Black Death.
# Student: Quelques années später, elle a perdu environ la moitié de sa population à la Black Death.
# ============================================
# Expert: However, these proteins only represent a small fraction of the total protein set-up necessary to build and maintain the structure and function of a particular type of plastid.
# Simple: Examples of plastids are: Plastids are one of the many different types of organelles in the cell.
# Teacher: These proteins are required to build and maintain the structure and function of a particular type of plastid.
# Student: Allerdings, diese Proteine stellen nur eine kleine Teile der gesamten Protein-Setups dar, die notwendig sind, um die Struktur und Funktion eines bestimmten Typs von plastid zu bauen und zu halten.
# ============================================
# Expert: Symptoms of pneumothorax include dyspnea and pleuritic chest pain. Dyspnea may be sudden or gradual in onset depending on the rate of development and size of the pneumothorax.
# Simple: Symptoms vary greatly depending on how much air enters the pleural space, how much of the lung collapses, and the person's lung function before the pneumothorax occurred. They range from none to a little shortness of breath or chest pain to severe shortness of breath, shock, and life -threatening cardiac arrest.
# Teacher: Dyspnea and pleuritic chest pain are two of the symptoms of a larger bacterial infection called pneumothorax.
# Student: Symptoms of pneumothorax include dyspnea and pleuritic chest pain.
# ============================================
# Expert: However, in infants, HIV\/AIDS patients, and others with weakened immunity, infection can cause serious and occasionally fatal illness ( toxoplasmosis ).
# Simple: But in infants, HIV\/AIDS patients, and others with weakened immunity, infection can cause serious and occasionally fatal illness ( toxoplasmosis ).
# Teacher: However, in infants, HIV/AIDS patients, and others with a weakened immune system, infection can cause serious and occasionally fatal illness ( toxoplasmosis ).
# Student: Allerdings, in infants, HIV/AIDS patients, and others with weakened immunity, infection can cause serious and occasionally fatal illness ( toxoplasmosis ).
# ============================================
# Expert: Central diabetes insipidus may also be secondary (acquired), caused by various lesions, including hypophysectomy, cranial injuries (particularly basal skull fractures), suprasellar and intrasellar tumors (primary or metastatic), Langerhans cell histiocytosis, lymphocytic hypophysitis, granulomas (sarcoidosis or tuberculosis), vascular lesions (aneurysm, thrombosis), and infections (encephalitis, meningitis).
# Simple: Other disorders that can cause central diabetes insipidus include accidental damage done during surgery on the hypothalamus or pituitary gland; a brain injury, particularly a fracture of the base of the skull; a tumor; sarcoidosis or tuberculosis; an aneurysm (a bulge in the wall of an artery) or blockage in the arteries leading to the brain; some forms of encephalitis or meningitis; and the rare disease Langerhans cell histiocytosis.
# Teacher: In people with central diabetes insipidus, the damaged nerves that control blood sugar (called the sweat glands) may become inflamed.
# Student: Central diabetes insipidus may also be secondary (acquired), caused by various lesions, including hypophysectomy, cranial injuries (particularly basal skull fractures), suprasellar and intrasellar tumors (primary or metastatic), Langerhans cell histiocytosis, lymphocytic hypophysitis, granulomas (sarcoidosis or tuberculosis),
# ============================================
# Expert: New South Greenland, sometimes known as Morrell 's Land, was an appearance of land recorded by the American captain Benjamin Morrell of the schooner Wasp in March 1823, during a sealing and exploration voyage in the Weddell Sea area of Antarctica.
# Simple: Morrel reported the sighting on the schooner Wasp in March 1823, during a seal hunting and exploration voyage in the Weddell Sea area of Antarctica.
# Teacher: New South Greenland, also known as Morrell's Land, was an appearance of land recorded by the American captain Benjamin Morrell of the schooner Wasp in March 1823, during a sealing and exploration voyage in the Antarctic Peninsula.
# Student: Greenland, sometimes known as Morrell's Land, was an appearance of land recorded by the American captain Benjamin Morrell of the schooner Wasp in March 1823, during a sealing and exploration voyage in the Weddell Sea area of Antarctica.
# ============================================
# Expert: In chronic sinusitis, CT is done more often, and x-rays of the apices of the teeth may be required in chronic maxillary sinusitis to exclude a periapical abscess.
# Simple: If a person has maxillary sinusitis, the teeth may be x-rayed to check for a tooth abscess.
# Teacher: If the infection is chronic, a CT scan of the inside of the sinus more often is needed.
# Student: In chronic maxillary sinusitis, CT is done more often, and x-rays of the apices of the teeth may be required in chronic maxillary sinusitis to exclude a periapical abscess.
# ============================================
# Expert: Gonorrheal infections are sometimes associated with burning or sharp penile pains during ejaculation.
# Simple: Gonorrheal infections are associated with burning or sharp penis pains during ejaculation.
# Teacher: A person may have burning or sharp pains in the pit of his or her lower abdomen when he or she ejects his or her penile tissue.
# Student: Gonorrheal infections are sometimes associated with burning or sharp penile pains during ejaculation.
# ============================================
# Expert: An interesting point presented in this paper is that the reaction of 1,2-dimethylidenecyclohexane with sulfur dioxide can give two different products depending on reaction conditions .
# Simple: They wrote that the reaction of 1,2-dimethylidenecyclohexane with sulfur dioxide can give two different products depending on reaction conditions .
# Teacher: It has been shown in this paper that the reaction of 1,2-dimethylidenecyclohexane with sulfur dioxide can give two different products depending on reaction conditions.
# Student: An interesting point presented in this paper is that the reaction of 1,2-dimethylidenecyclohexane with sulfur dioxide can give two different products depending on reaction conditions.
# ============================================
# Expert: Some patients develop hypersensitivity to the localized respiratory infection, manifested by arthritis, conjunctivitis, erythema nodosum, or erythema multiforme.
# Simple: Some people have an allergic reaction to the fungus, which can cause joint pain, conjunctivitis, and a rash of tender red or violet bumps or patches (called erythema nodosum).
# Teacher: In these people, the localized respiratory infection is the disease that causes the allergic reaction.
# Student: Some patients develop hypersensitivity to the localized respiratory infection, manifeste by arthritis, conjunctivitis, erythema nodosum, or erythema multiforme.
# ============================================
# Expert: Treatment of a Grignard reagent with oxygen gives the magnesium organoperoxide.
# Simple: The oxidation of a Grignard reagent with oxygen takes place through a radical intermediate to a magnesium hydroperoxide.
# Teacher: Treatment of a Grignard reagent with oxygen gives the magnesium organoperoxide.
# Student: a Grignard reagent with oxygen gives the magnesium organoperoxide.
# ============================================
# Expert: Marchers stretched from Avenue d'Eylau, where the author was living, down the Champs Ales, and all the way to the center of Paris.
# Simple: Marchers stretched from Avenue d'Eylau, down the Champs Ales, and all the way to the center of Paris.
# Teacher: Marchers stretched from Avenue d'Eylau, down the Champs Ales, and all the way to the center of Paris.
# Student: Marchers stretched from Avenue d'Eylau, where the author was living, down the Champs Ales, and all the way to the center of Paris.
# ============================================
# Expert: Goldbach 's conjecture is one of the oldest and best-known unsolved problems in number theory and all of mathematics.
# Simple: Goldbach 's conjecture is one of the oldest unsolved problems in number theory and in all of mathematics.
# Teacher: Goldbach's conjecture is one of the oldest and best-known unsolved problems in number theory and all of mathematics.
# Student: Goldbach's conjecture is one of the oldest and best-known unsolved problems in number theory and all of mathematics.
# ============================================
# Expert: Certain factors can worsen symptoms: Prolonged visual efforts (eg, reading, working on the computer, driving, watching television); Local environments that are dry, windy, dusty, or smoky; Certain systemic drugs, including isotretinoin, sedatives, diuretics, antihypertensives, oral contraceptives, and all anticholinergics (including antihistamines and many GI drugs); Dehydration.
# Simple: Symptoms are worsened by Activities in which the rate of blinking is reduced, specifically those that involve prolonged use of the eyes, such as reading, working at a computer, driving, or watching television; Windy, dusty, or smoky areas and dry environments, such as in airplanes or in shopping malls; areas with low humidity; and areas where air conditioners (especially in the car), fans, or heaters are being used; The use of certain drugs, including isotretinoin and some tranquilizers, diuretics, antihypertensives, oral contraceptives, and antihistamines, and other drugs with anticholinergic effects.
# Teacher: Certain factors can worsen symptoms: Prolonged visual efforts (eg, reading, working on the computer, watching television); Dry, windy, dusty, or smokey environments; Prolonged exposure to the sun; Certain systemic drugs (including isotretinoin, diuretics, antihypertensives, oral contraceptives, and all anticholinergics) and dehydration.
# Student: Certain factors can worsen symptoms: Prolonged visual efforts (eg, reading, working on the computer, driving, watching television) Local environments that are dry, windy, dusty, or smoky Certain systemic drugs, including isotretinoin, sedatives, diuretics, antihypertensives, oral contraceptives, and all anticholinergics (including antihistamines and many GI drugs) De
# ============================================
# Expert: Resistance to many of the antibiotics used to treat this condition is increasing.
# Simple: resistance to many of the antibiotics used to treat this condition, however, is increasing.
# Teacher: There are many reasons why bacteria can become resistant to some antibiotics used to treat malaria.
# Student: Resistance to many of the antibiotics used to treat this condition is increasing.
# ============================================
# Expert: The cough is usually mild compared to that accompanying influenza.
# Simple: The cough caused by a cold is usually mild compared to a cough caused by influenza ( the flu ).
# Teacher: The cough caused by a cold is usually mild compared to a cough caused by the flu ( influenza ).
# Student: The cough is usually mildcompared to that accompanying influenza.
# ============================================
# Expert: The Nitrone-olefin cycloaddition is a ( 3+2 ) cycloaddition.
# Simple: The Nitrone-olefin cycloaddition is a [ 3+2 ] cycloaddition.
# Teacher: The Nitrone-olefin cycloaddition is a [ 3+2 ] cycloaddition.
# Student: cycloaddition Nitrone-olefin is a ( 3+2 ) cycloaddition.
# ============================================
# Expert: Myocardial fibrosis, left ventricular hypertrophy, and cardiomyopathy can develop.
# Simple: Chronic use can also damage the heart, causing scarring and thickening of the heart muscle and eventually leading to heart failure.
# Teacher: Deterioration of heart muscle and heart muscle cells can result in heart failure.
# Student: Myocardial fibrosis, left ventricular hypertrophie, and cardiomyopathy can develop.
# ============================================
# Expert: Acute pain, erythema, and swelling most commonly affect the pinna cartilage.
# Simple: Typically, one ear or both ears (but not the ear lobes) become red, swollen, and very painful.
# Teacher: The pinna cartilage is the most commonly injured part of the joint.
# Student: Schmerzen, erythema, and swelling most commonly affect the cartilage of the pinna.
# ============================================
# Expert: Without treatment, postpartum depression can resolve spontaneously or become chronic depression.
# Simple: Without treatment, postpartum depression can last for months or years.
# Teacher: Depression following childbirth can resolve spontaneously or progress to depression after the child is born.
# Student: Ohne Behandlung kann die postpartume Depression spontan oder zu einer chronic depression werden.
# ============================================
# Expert: Nonspecific symptoms develop a few weeks, months, or occasionally years after primary infection; they include low-grade fever, anorexia, weight loss, and weakness.
# Simple: The progressive form may develop weeks, months, or even years after the initial infection. Symptoms include mild fever and loss of appetite, weight, and strength.
# Teacher: These symptoms include a low grade fever, weight loss, and a feeling of general weakness.
# Student: symptoms develop several weeks, months, or occasionally years after primary infection they include low-grade fever, anorexia, weight loss, and weakness.
# ============================================
# Expert: Laboratory tests should be done to screen for anemia, hypoalbuminemia, and electrolyte abnormalities. Liver function tests should be done; elevated alkaline phosphatase and gammaÃ¢ÂÂglutamyl transpeptidase levels in patients with major colonic involvement suggest possible primary sclerosing cholangitis. Leukocytosis or increased levels of acute-phase reactants (eg, ESR, C-reactive protein) are nonspecific but may be used serially to monitor disease activity. To detect nutritional deficiencies, levels of vitamin D and B12 should be checked every 1 to 2 years. Additional laboratory measurements, such as levels of water-soluble vitamins (folic acid and niacin), fat -soluble vitamins (A, D, E and K), and minerals (zinc, selenium, and copper), may be checked when deficiencies are suspected.
# Simple: No laboratory test specifically identifies Crohn disease, but blood tests may show anemia, abnormally high numbers of white blood cells, low levels of the protein albumin, and other indications of inflammation, such as an elevated erythrocyte sedimentation rate or level of C-reactive protein. A doctor may also do tests to determine how the liver is functioning.
# Teacher: Laboratory tests should be done to screen for anemia, hypoalbuminemia, and electrolyte abnormalities. Liver function tests should be done; elevated levels of alkaline phosphatase or gammaglutamyl transpeptidase in people with a large colon suggest sclerosing cholangitis. Leukocytosis or increased levels of acute-phase reactants (eg, ESR, C-reactive protein) are nonspecific but may be used
# Student: ,, and electrolyte abnormalities. Liver function tests should be done elevated alkaline phosphatase and gammaglutamyl transpeptidase levels in patients with major colonic involvement suggest possible primary sclerosing cholangitis. Laboratory tests should be done to screen for anemia, hypoalbuminemia, and electrolyte abnormalities. To detect nutritional deficiencies, levels of vitamin D and B12 should be checked every 1 to 2 years
# ============================================
# Expert: Women are twice as likely to suffer from specific phobias as men .
# Simple: Females are almost twice as likely to suffer from specific phobias as males .
# Teacher: Women are twice as likely to be phobic as men.
# Student: Women are twice as likely to suffer from specific phobias as men.
# ============================================
# Expert: Mechanical methods include crushing of the Mg pieces in situ, rapid stirring, and sonication of the suspension.
# Simple: Mechanical methods include crushing of the Mg pieces in situ, rapid stirring, or using ultrasound ( sonication ) of the suspension.
# Teacher: For example, Mg pieces can be crushed in situ, and the solution may be allowed to cool.
# Student: Mechanical methods include crushing of the Mg pieces in situ, rapid stirring, and sonication of the suspension.
# ============================================
# Expert: Temperature is > 40Â° C.
# Simple: Body temperature usually exceeds 104Â° F (40Â° C) and may be so high that it exceeds the markings on a typical thermometer.
# Teacher: Thermoglobin is in the blood, and it is at or near room temperature.
# Student:
# ============================================
# Expert: Generalized or focal alopecia is common during active phases of SLE.
# Simple: Generalized or patchy loss of hair (alopecia) is common during flare-ups.
# Teacher: Alopecia areata (male pattern baldness) is common in people with SLE.
# Student: Während der aktiven Phasen des SLE, ist eine allgemeine oder focale Alopecia häufig.
# ============================================
# Expert: The extent of HIV progression is typically determined by measuring the percentage of CD4+ T cells in the patient 's blood HIV ultimately progresses to acquired immune deficiency syndrome ( AIDS ).
# Simple: The extent of HIV progression is found by measuring the percentage of CD4+ T cells in the patient 's blood.
# Teacher: If the virus is not treated, the body will produce insufficient amounts of the antiretroviral antibody called ritonin.
# Student: The extent of HIV progression is typically determined by measuring the percentage of CD4+ T cells in the patient's blood HIV ultimately progresses to acquired immune deficiency syndrome ( AIDS ).
# ============================================
# Expert: The most common causative organisms of occult bacteremia are Streptococcus pneumoniae and Haemophilus influenzae. The widespread use of vaccinations against both of these organisms has made occult bacteremia much less common.
# Simple: Children under 3 years old who develop a fever (particularly if their temperature is 102.2Â° F [ 39Â° C ] or higher) sometimes have bacteria in their bloodstream (bacteremia). Unlike older children, they sometimes have bacteremia with no symptoms besides fever (called occult bacteremia). Routine vaccines against the bacteria that usually cause occult bacteremia (Streptococcus pneumoniae and Haemophilus influenzae type b [ Hib ]) are now widely used in the United States and Europe. As a result, these vaccines have nearly eliminated occult bacteremia in children in this age group.
# Teacher: The most common causes of occult bacteremia are Streptococcus pneumoniae and Haemophilus influenzae.
# Student: occult bacteremia are Streptococcus pneumoniae and Haemophilus influenzae.
# ============================================
# Expert: Brain injury is likely if respiratory arrest goes untreated for more than three minutes, and death is almost certain if more than five minutes.
# ...
# Teacher: Stress, desire for control, and sexual abuse are also some of the functional causes of stool retention and subsequent constipation.
# Student: Stress, desire for control, and sexual abuse are also some of the functional causes of stool retention and subsequent constipation.
# ============================================
# Expert: A GI or respiratory prodrome may precede these symptoms. Meningeal signs are typically mild and less prominent than other manifestations.
# Simple: Before symptoms of encephalitis start, people may have digestive symptoms, such as nausea, vomiting, diarrhea, or abdominal pain. Or they may feel as if they are getting a cold or the flu and have cough, fever, a sore throat, a runny nose, swollen lymph nodes, and muscle aches.
# Teacher: A GI or respiratory prodrome may precede these symptoms. Meningioencephalitis usually presents as a mild, dilated brain mass.
# Student: . are typically mild and less prominent than other manifestations. Meningeal signs are typically mild and less prominent than other manifestations.
# ============================================
# Expert: About 1/1000 hypertensive patients has a pheochromocytoma.
# Simple: Pheochromocytomas may be quite small.
# Teacher: About 1/1000 of all hypertensive patients has a pheochromocytoma.
# Student: 1/1000 hypertensive patients have a pheochromocytoma.
# ============================================
# Expert: B cells mature into B lymphocytes in the bursa equivalent, which in humans is the GALT, which is thought to be located in the Peyer 's patches of the intestine, while T cells migrate to and mature in a distinct organ, called the thymus.
# Simple: B cells mature into B lymphocytes in the bone marrow, while T cells migrate to and mature in a distinct organ, called the thymus.
# Teacher: B cells mature into B lymphocytes in the bursa equivalent, which in humans is the GALT, which is thought to be located in the intestines near the peyer's patches.
# Student: B cells mature into B lymphocytes in the bursa equivalent, which in humans is the GALT, which is thought to be located in the Peyer's patches of the intestine, while T cells migrate to and mature in a distinct organ, called the thymus.
# ============================================
# Expert: Postpartum depression interferes with women's ability to care for themselves and the baby.
# Simple: Women may not bond with their baby.
# Teacher: Postpartum depression interferes with women's ability to care for themselves and their baby.
# Student: Postpartum depression interferes with women's ability to care for themselves and the baby.
# ============================================
# Expert: Pancreatitis is common.
# Simple: The pancreas may become inflamed (called pancreatitis), causing severe abdominal pain and vomiting.
# Teacher: Most people with pancreatitis do not know what pancreatitis is.
# Student: Pankreattitis is common.
# ============================================
# Expert: Urine may be cola-colored in glomerulonephritis or myoglobinuria.
# Simple: The passing of cola-colored urine may indicate a number of kidney diseases that damage the glomeruli, the filtering units of the kidney. The brown color results from blood passing through the filtering units and may be the first sign of a condition known as a glomerulonephritis (inflammation of the filtering units).
# Teacher: Urine may be cola-colored in glomerulonephritis or in myoglobinuria.
# Student: Urine may be cola-colored in glomerulonephritis or myoglobinuria.
# ============================================
# Expert: Physiologic tremor occurs in otherwise healthy people. It is an action or postural tremor that tends to affect both hands about equally; amplitude is usually fine. It is often noticeable only when certain stressors are present. These stressors include Anxiety; Fatigue; Exercise; Sleep deprivation; Withdrawal of alcohol or certain other CNS depressant drugs (eg, benzodiazepines, opioids); Certain disorders (eg, hyperthyroidism), when symptomatic; Consumption of caffeine or recreational drugs such as cocaine, amphetamines, or phencyclidine; Use of certain therapeutic drugs, such as theophylline, beta-adrenergic agonists, corticosteroids, and valproate. There are many causes (see table Some Causes of Tremor), but the most common are For action or postural tremors: Essential tremor; For resting tremors: Parkinson disease; For intention tremors: Cerebellar dysfunction (eg, due to a stroke, trauma, or multiple sclerosis). Drugs (see table Some Causes of Tremor by Type) can cause or aggravate different types of tremor. Low doses of some sedatives (eg, alcohol) may relieve some tremors (eg, essential and physiologic tremor); higher doses may cause or exacerbate tremor.
# Simple: Most commonly, tremors are Physiologic tremor (most common overall); Essential tremor; Due to Parkinson disease; Due to a stroke or multiple sclerosis affecting parts of the brain that control movement; Due to liver disease; Due to alcohol withdrawal; Due to an overactive thyroid gland (hyperthyroidism); Due to hereditary disorders involving the cerebellum, such as Friedreich ataxia and spinocerebellar ataxias; Due to use of certain drugs or exposure to certain toxic substances; Psychogenic tremor (due to psychologic factors). Sometimes there is more than one cause of the tremors.
# Teacher: Physiologic tremor occurs in otherwise healthy people. It is an action or postural tremor that affects both hands about equally; amplitude is usually fine.
# Student: tremors: Parkinson disease For intention tremors: Cerebellar dysfunction (eg, due to a stroke, trauma, or multiple sclerosis). Drugs (see table Some Causes of Tremor by Type) can cause or aggravate different types of tremor. Low doses of some sedatives (eg, alcohol) may relieve some tremors (eg, essential and physiologic tremor) higher doses may cause or exacerbate tremor.
# ============================================
# Expert: Imaging studies
# Simple: Imaging tests
# Teacher: The most common medical conditions.
# Student: Imaging studies
# ============================================
# Expert: The most common causes of delirium are the following: Drugs, particularly anticholinergics, psychoactive drugs, and opioids; Dehydration; Infection. Many other conditions can cause delirium (see Table: Causes of Delirium).
# Simple: Overall, the most common causes of delirium are the following: Drugs, particularly drugs with anticholinergic effects, psychoactive drugs, and opioids; Dehydration; Infections, such as pneumonia, a bloodstream infection (sepsis), infections that affect the whole body or cause a fever, and urinary tract infections; Kidney failure, liver failure, and a low level of oxygen in the blood (hypoxia, as can occur in pneumonia), especially when these disorders begin suddenly and progress rapidly. Other causes include hospitalization, surgery, withdrawal of a drug, certain disorders, and poisons.
# Teacher: Drugs, particularly anticholinergics, psychoactive drugs, and opioids; Dehydration; Infection.
# Student: delirium are: Drugs, particularly anticholinergics, psychoactive drugs, and opioids Dehydration Infection.
# ============================================
# Expert: Fasting plasma glucose and a lipid profile.
# Simple: Blood tests to measure sugar and fat (lipid) levels.
# Teacher: Plasma glucose and a lipid profile.
# Student: Fasting plasma glucose and a lipid profile.
# ============================================
# Expert: He died of senile dementia in the Fremantle Lunatic Asylum ( now the Fremantle Arts Centre building ) on 13 August 1900 , and was buried in Fremantle Cemetery .
# Simple: He died of senile dementia in the Fremantle Lunatic Asylum ( now the Fremantle Arts Centre building ) on 13 August , 1900 .
#
# Teacher: He died of senile dementia in the Fremantle Lunatic Asylum ( now the Fremantle Arts Centre building ) on 13 August 1900, and was buried in Fremantle Cemetery.
# Student: Er hat senile dementia in the Fremantle Lunatic Asylum ( now the Fremantle Arts Centre building ) on 13 August 1900, and was buried in Fremantle Cemetery.
# ============================================
# Expert: These studies into the relationship between the effects of emotions and perceptions on the autonomic nervous system , namely the sympathetic and parasympathetic responses that initiated the recognition of the freeze , fight or flight response .
# Simple: These studies into the relationship between the effects of emotions and perceptions on the autonomic nervous system , the responses that led to the freeze , fight or flight response .
#
# Teacher: These studies looked at the relationship between the emotions and actions of the nervous system, namely the sympathetic and parasympathetic responses that initiated the recognition of the freeze, fight or flight response.
# Student: These studies into the relationship between the effects of emotions and perceptions on the autonomic nervous system,namely the sympathetic and parasympathetic responses that initiated the recognition of the freeze, fight or flight response.
# ============================================
# Expert: Gertrude Baines married Sam Conley at a `` very young age '' and had a daughter , Annabelle , born in 1909 , who died of typhoid fever at the age of 18 .
# Simple: Gertrude Baines married Sam Conley at a very young age and had one daughter who died of typhoid fever at the age of 18 .
#
# Teacher: Gertrude Baines married Sam Conley at  a very young age '' and had a daughter, Annabelle, born in 1909.
# Student: Gertrude Baines married Sam Conley at a  very young age '' and had a daughter, Annabelle, born in 1909, who died of typhoid fever at the age of 18.
# ============================================
# Expert: A chest x-ray and testing for TB and HIV infection should be done in patients with weight loss or risk factors for those infections.
# Simple: Skin tests, chest x-ray, and sometimes computed tomography (CT) of the chest, and examination and culture of a sputum sample for tuberculosis, and blood tests for HIV infection are also done if people have lost weight or have risk factors for these disorders.
# Teacher: A chest x-ray and testing for TB and HIV infection should be done in people who have lost weight.
# Student: TB and HIV infection should be done in patients with weight loss or risk factors for those infections.
# ============================================
# Expert: The most commonly used nuclei are 1H and 13C, although isotopes of many other elements ( e.g.
# Simple: The most commonly studied nuclei are 1H and 13C, although nuclei from isotopes of many other elements ( e.g.
# Teacher: In chemistry, the most commonly used nuclei are 1H and 13C, although isotopes of many other elements ( e.g., cobalt, tin, cobalt, tin, tungsten, tin, tungsten ) are also used.
# Student: The most commonly used nuclei are 1H and 13C, although isotopes of many other elements (e.g.
# ============================================
# Expert: Because loss may be focal, patients may retain more aspects of mental function.
# Simple: Symptoms can vary depending on what part of the brain is destroyed.
# Teacher: Symptoms may be focal in nature, meaning that some aspects of mental function may be present.
# Student: Da Verluste aufgrund der zentralen Ursachen der psychischen Störungen bedingt sind, können Patienten mehr Aspekte der mentalen Funktion behalten.
# ============================================
# Expert: Prodromal (pre- icteric) phase: Nonspecific symptoms occur; they include profound anorexia, malaise, nausea and vomiting, a newly developed distaste for cigarettes (in smokers), and often fever or right upper quadrant abdominal pain.
# Simple: Symptoms of acute viral hepatitis usually begin suddenly. They include A poor appetite; A general feeling of illness (malaise); Nausea and vomiting; Often a fever; Often pain in the upper right part of the abdomen (where the liver is located).
# Teacher: Symptoms include severe anorexia, malaise, nausea and vomiting, a new found dislike for cigarettes (in smokers), and often fever or right upper quadrant abdominal pain.
# Student: Prodromal phase: Nonspecific symptoms occur they include profound anorexia, malaise, nausea and vomiting, a newly developed distaste for cigarettes (in smokers), and often fever or right upper quadrant abdominal pain.
# ============================================
# Expert: A chest x-ray should be done in patients with chronic cough in whom presumptive treatment is ineffective. If the x-ray findings are unremarkable, many clinicians sequentially test for asthma (pulmonary function tests with methacholine challenge if standard spirometry is normal), sinus disease (sinus CT), and gastroesophageal reflux disease (esophageal pH monitoring).
# Simple: If cough is not relieved, doctors typically do tests in the following order until a test suggests a diagnosis: A chest x-ray; Pulmonary function tests to check for asthma; CT of the sinuses to check for sinus disorders; Placement of an acid sensor in the esophagus to check for gastroesophageal reflux disease. If people have a chronic cough, doctors usually do a chest x-ray.
# Teacher: A chest x-ray should be done in people who cough up blood. If the image on the x-ray is normal, tests are often done to rule out other conditions such as pneumonia, sinusitis, or GERD.
# Student: ,, with chronic cough, in whom presumptive treatment is ineffective., many clinicians sequentially test for asthma (pulmonary function tests with methacholine challenge if standard spirometry is normal), sinus disease (sinus CT) and gastroesophageal reflux disease (esophageal pH monitoring).
# ============================================
# Expert: Wheat and rye breads are consumed in Belarus, but rye is more plentiful because conditions are too harsh for growing wheat.
# Simple: Rye is more plentiful because conditions are too harsh for growing wheat.
# Teacher: Rye bread is more common in Belarus than wheat bread.
# Student: , but rye is more plentiful because conditions are too harsh for growing wheat.
# ============================================
# Expert: Chronic, heavy infection can lead to iron deficiency anemia, causing pallor, dyspnea, weakness, tachycardia, lassitude, and peripheral edema. A low - grade eosinophilia is often present.
# Simple: Over time, severe infections cause anemia as blood is lost, and people become iron deficient. Anemia causes fatigue.
# Teacher: Chronic, heavy infection can lead to iron deficiency anemia, causing pallor, dyspnea, weakness, tachycardia, lassitude, and peripheral edema.
# Student: Chronic, heavy infection can lead to iron deficiency anemia, causing pallor, dyspnea, weakness, tachycardia, lassitude, and peripheral edema.
# ============================================
# Expert: In long-standing cases, blood vessels may grow in from the limbus (corneal neovascularization).
# Simple: Corneal ulcers may heal with treatment, but they may leave a cloudy scar that impairs vision.
# Teacher: In severe cases, blood vessels may grow from the side of the limb up the leg.
# Student: In long-standing cases, blood vessels may grow in from the limbus (neovascularization).
# ============================================
# Expert: Small- bowel transplantation is advocated for patients who are not candidates for long- term TPN and in whom adaptation does not occur.
# Simple: Small intestine transplantation is an alternative for people who do not adapt to their short bowel and who can not tolerate long- term TPN.
# Teacher: Small- bowel transplantation is recommended for people who are not candidates for long- term TPN and in whom adaptation does not occur.
# Student: Small- bowel transplantation is advocated for patients who are not candidates for long-term TPN and in which adaptation does not occur.
# ============================================
